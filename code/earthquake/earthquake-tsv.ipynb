# %%
import pandas as pd

# %%
pd.set_option('display.max_colwidth', None)
# Mengatur opsi tampilan
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("../../datasets/earthquake/katalog_gempa_v2.tsv", sep="\t")
df
# Out:
# C:\Users\whisn\AppData\Local\Temp\ipykernel_18620\3651689899.py:1: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../../datasets/earthquake/katalog_gempa_v2.tsv", sep="\t")
#         Unnamed: 0      eventID                          datetime  latitude  \
# 0                0  bmg2008vkye  2008-11-01 00:31:25.143741+00:00 -0.604440
# 1                1  bmg2008vlag  2008-11-01 01:34:29.660856+00:00 -6.611860
# 2                2  bmg2008vlaj  2008-11-01 01:38:14.802129+00:00 -3.650586
# 3                3  bmg2008vlbt  2008-11-01 02:20:05.909515+00:00 -4.198925
# 4                4  bmg2008vlcd  2008-11-01 02:32:18.756155+00:00 -4.091891
# ...            ...          ...                               ...       ...
# 102510      102510  bmg2023hixb  2023-04-15 11:29:36.021477+00:00  0.318344
# 102511      102511  bmg2023hixg  2023-04-15 11:35:19.301737+00:00 -7.627348
# ...

# %%
df['mag_type'].value_counts()
# Out:
# M         52291
# MLv       42399
# mb         4392
# Mw         1580
# Mw(mB)     1221
# ML          110
# mB            7
# Mwp           3
# Name: mag_type, dtype: int64
