# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../../datasets/annual-number-of-deaths-by-cause.csv")
df.head()
# Out:
#         Entity Code  Year Number of executions (Amnesty International)  \
# 0  Afghanistan  AFG  2007                                           15
# 1  Afghanistan  AFG  2008                                           17
# 2  Afghanistan  AFG  2009                                            0
# 3  Afghanistan  AFG  2011                                            2
# 4  Afghanistan  AFG  2012                                           14
#
#    Deaths - Meningitis - Sex: Both - Age: All Ages (Number)  \
# 0                                             2933.0
# 1                                             2731.0
# 2                                             2460.0
# 3                                             2327.0
# 4                                             2254.0
#
#    Deaths - Alzheimer's disease and other dementias - Sex: Both - Age: All Ages (Number)  \
# 0                                             1402.0
# 1                                             1424.0
# ...

# %%
df['Total'] = df.iloc[:, 3:].sum(axis=1)
df.head()
# Out:
# C:\Users\whisn\AppData\Local\Temp\ipykernel_20932\3069907029.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df['Total'] = df.iloc[:, 3:].sum(axis=1)
#         Entity Code  Year Number of executions (Amnesty International)  \
# 0  Afghanistan  AFG  2007                                           15
# 1  Afghanistan  AFG  2008                                           17
# 2  Afghanistan  AFG  2009                                            0
# 3  Afghanistan  AFG  2011                                            2
# 4  Afghanistan  AFG  2012                                           14
#
#    Deaths - Meningitis - Sex: Both - Age: All Ages (Number)  \
# 0                                             2933.0
# 1                                             2731.0
# ...

# %%
# Menghapus kolom ke-4 sampai kolom terakhir - 1
df = df.drop(df.columns[3:-1], axis=1)
df.head(100000)
# Out:
#            Entity Code  Year     Total
# 0     Afghanistan  AFG  2007  409592.0
# 1     Afghanistan  AFG  2008  400418.0
# 2     Afghanistan  AFG  2009  391854.0
# 3     Afghanistan  AFG  2011  393118.0
# 4     Afghanistan  AFG  2012  400728.0
# ...           ...  ...   ...       ...
# 6888     Zimbabwe  ZWE  2015  260160.0
# 6889     Zimbabwe  ZWE  2016  256548.0
# 6890     Zimbabwe  ZWE  2017  253030.0
# 6891     Zimbabwe  ZWE  2018  247012.0
# 6892     Zimbabwe  ZWE  2019  247080.0
#
# [6893 rows x 4 columns]

# %%
year = [2015, 2016, 2017, 2018, 2019]
non_commununicable

# %%
print("Total Deaths 2015", df[df['Year'] == 2015]['Total'].sum()) 
print("Total Deaths 2016", df[df['Year'] == 2016]['Total'].sum()) 
print("Total Deaths 2017", df[df['Year'] == 2017]['Total'].sum()) 
print("Total Deaths 2018", df[df['Year'] == 2018]['Total'].sum()) 
print("Total Deaths 2019", df[df['Year'] == 2019]['Total'].sum())
# Out:
# Total Deaths 2014 601615382.0
# Total Deaths 2015 608717832.0
# Total Deaths 2016 614595808.0
# Total Deaths 2017 620147496.0
# Total Deaths 2018 629557508.0
# Total Deaths 2019 639657204.0
